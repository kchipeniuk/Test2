# %%
using PyPlot
using Distributions
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\chipeniukk\.julia\compiled\v1.2\PyPlot\oatAj.ji for PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1240
# ┌ Info: Recompiling stale cache file C:\Users\chipeniukk\.julia\compiled\v1.2\Distributions\xILW0.ji for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# └ @ Base loading.jl:1240

# %%
x = range(0,2,length=100)
# Out:
# 0.0:0.020202020202020204:2.0

# %%
y=x.*x
# Out:
# 100-element Array{Float64,1}:
#  0.0
#  0.0004081216202428324
#  0.0016324864809713297
#  0.0036730945821854917
#  0.006529945923885319
#  0.010203040506070809
#  0.014692378328741967
#  0.019997959391898783
#  0.026119783695541274
#  0.03305785123966942
#  0.040812162024283234
#  0.04938271604938271
#  0.05876951331496787
#  ⋮
#  3.1604938271604937
#  3.232731353943475
#  3.305785123966942
#  3.379655137230895
#  3.454341393735333
#  3.5298438934802574
#  3.6061626364656667
#  3.683297622691562
#  3.7612488521579435
#  3.8400163248648096
#  3.9196000408121625
#  4.0

# %%
plot(x,y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000034A0AA58>

# %%
d = Normal()
# Out:
# Normal{Float64}(μ=0.0, σ=1.0)

# %%
x = rand(d,100)
# Out:
# 100-element Array{Float64,1}:
#  -0.6978883419025066
#  -1.1834370861099088
#   1.0864059367631989
#   0.40549648155274143
#  -0.5624448008484685
#   1.079788212435446
#   1.2810699419307154
#  -0.20345352189014845
#  -0.0652321216600464
#  -2.0560644769332828
#  -0.055327139601239236
#   0.23402641262752388
#  -0.30970605552994884
#   ⋮
#   1.4766263158771586
#   0.9094984398135866
#  -2.350454525425507
#  -1.7820136512502058
#   0.3053912613257359
#  -0.23008466788609078
#   0.45979052337854687
#   0.23275484270566885
#   0.4678284885851552
#   0.718207826928215
#   0.028459862374245356
#   0.8664521048451717
